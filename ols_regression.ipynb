# %%
import os
import numpy as np
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col

# %%
# Set directory path to current directory
dir_path = os.path.abspath('')

# Getting the data for anlaysis
dataset = os.path.join(dir_path, 'results_v1.xlsx')

# Turning the data into a dataframe
df = pd.read_excel(dataset, index_col=0, sheet_name="full_data")

# %%
df.index = pd.Series(df.index).fillna(method='ffill')

# %%
for name, group in df.groupby('country'):
    # print(name)
    
    y=group['elec_rate']

    # Model 1: The multiple regression model describes the response as a weighted sum of the predictors:(Elec = beta_0 + beta_1*ED + beta_2*EG,nr ~)
    X0 = (group[['Energy distribution',
                'Energy generation, non-renewable sources',
                'Energy Policy',
                'Energy generation, renewable sources'                  
                ]])
    
    X0 = sm.add_constant(X0)
    
    reg0 = sm.OLS(y, X0).fit()
    
    reg0.summary()
# Out:
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   "anyway, n=%i" % int(n))

# %%
# Iterate through the dataframe and perform regression on each country

for name, group in df.groupby('country'):
    # print(name)
    y=group['elec_rate']

    # Model 1: The multiple regression model describes the response as a weighted sum of the predictors:(Elec = beta_0 + beta_1*ED + beta_2*EG,nr ~)
    X0 = group[['Energy distribution',
                'Energy generation, non-renewable sources',
                'Energy Policy',
                'Energy generation, renewable sources'                  
                ]]
    
    X0 = sm.add_constant(X0)
    
    reg0 = sm.OLS(y, X0).fit()
    
    # reg0.summary()
    # by normalizing to get the coefficient value to show a bit bigger
    
    results = summary_col([reg0],stars=True,float_format='%0.8f',
                       model_names=['Model 1'],
                       info_dict={'N':lambda x: "{0:d}".format(int(x.nobs)),
                                  'R2':lambda x: "{:.2f}".format(x.rsquared)})

    print(results) 
    
    # print('Country: {}  \nR^2 value for model 1 is: {:.2f},  \nfor model 2 is: {:.2f}'.format(name, reg0.rsquared, reg1.rsquared))
# Out:
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    37.17436451***
#                                          (1.65656045)
# Energy distribution                      0.00000624**
#                                          (0.00000222)
# Energy generation, non-renewable sources -0.00000024
#                                          (0.00000956)
# Energy Policy                            -0.00000219*
#                                          (0.00000109)
# Energy generation, renewable sources     -0.00000112***
#                                          (0.00000030)
# R-squared                                0.57732857
# R-squared Adj.                           0.44727582
# N                                        18
# R2                                       0.58
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    33.73813975***
#                                          (2.53262007)
# Energy distribution                      -0.00000046
#                                          (0.00000026)
# Energy generation, non-renewable sources 0.00000117
#                                          (0.00000458)
# Energy Policy                            0.00000031
#                                          (0.00000049)
# Energy generation, renewable sources     -0.00000070
#                                          (0.00000105)
# R-squared                                0.36534966
# R-squared Adj.                           0.17007263
# N                                        18
# R2                                       0.37
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    45.41421372***
#                                          (3.29514005)
# Energy distribution                      0.00000061
#                                          (0.00000111)
# Energy generation, non-renewable sources 0.00002281
#                                          (0.00001574)
# Energy Policy                            0.00002509**
#                                          (0.00001143)
# Energy generation, renewable sources     -0.00002016
#                                          (0.00002297)
# R-squared                                0.47249618
# R-squared Adj.                           0.31018732
# N                                        18
# R2                                       0.47
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    14.77903297***
#                                          (1.31923226)
# Energy distribution                      -0.00000009
#                                          (0.00000010)
# Energy generation, non-renewable sources 0.00000023
#                                          (0.00000019)
# Energy Policy                            -0.00000002
#                                          (0.00000010)
# Energy generation, renewable sources     -0.00000002
#                                          (0.00000015)
# R-squared                                0.26635635
# R-squared Adj.                           0.04061984
# N                                        18
# R2                                       0.27
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ======================================================
#                                             Model 1
# ------------------------------------------------------
# const                                    7.43513836***
#                                          (0.70763505)
# Energy distribution                      0.00000014
#                                          (0.00000017)
# Energy generation, non-renewable sources -0.00000051
#                                          (0.00000033)
# Energy Policy                            -0.00000067
#                                          (0.00000052)
# Energy generation, renewable sources     -0.00000017*
#                                          (0.00000009)
# R-squared                                0.47172375
# R-squared Adj.                           0.30917721
# N                                        18
# R2                                       0.47
# ======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    82.45067118***
#                                          (3.81456501)
# Energy distribution                      -0.00000082
#                                          (0.00000081)
# Energy generation, non-renewable sources -0.00000022
#                                          (0.00000043)
# Energy Policy                            -0.00000042
#                                          (0.00000265)
# Energy generation, renewable sources     0.00000021
#                                          (0.00000070)
# R-squared                                0.20191770
# R-squared Adj.                           -0.04364608
# N                                        18
# R2                                       0.20
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    54.83667777***
#                                          (2.00255455)
# Energy distribution                      -0.00000002
#                                          (0.00000015)
# Energy generation, non-renewable sources -0.00000030
#                                          (0.00000036)
# Energy Policy                            0.00000008
#                                          (0.00000020)
# Energy generation, renewable sources     -0.00000009
#                                          (0.00000017)
# R-squared                                0.20279406
# R-squared Adj.                           -0.04250007
# N                                        18
# R2                                       0.20
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    11.64094149***
#                                          (0.80821224)
# Energy distribution                      -0.00001172**
#                                          (0.00000515)
# Energy generation, non-renewable sources -0.00015078*
#                                          (0.00007877)
# Energy Policy                            -0.00000079
#                                          (0.00000092)
# Energy generation, renewable sources     0.00000504
#                                          (0.00000606)
# R-squared                                0.40009097
# R-squared Adj.                           0.21550357
# N                                        18
# R2                                       0.40
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ======================================================
#                                             Model 1
# ------------------------------------------------------
# const                                    5.92019360***
#                                          (0.52973553)
# Energy distribution                      -0.00000077*
#                                          (0.00000037)
# Energy generation, non-renewable sources 0.00000166***
#                                          (0.00000046)
# Energy Policy                            -0.00000045
#                                          (0.00000046)
# Energy generation, renewable sources     0.00000126
#                                          (0.00000078)
# R-squared                                0.65825640
# R-squared Adj.                           0.55310453
# N                                        18
# R2                                       0.66
# ======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    71.09935558***
#                                          (2.68792358)
# Energy distribution                      -0.00000113
#                                          (0.00000532)
# Energy generation, non-renewable sources -0.00000494
#                                          (0.00000594)
# Energy Policy                            -0.00003408**
#                                          (0.00001511)
# Energy generation, renewable sources     -0.00000592
#                                          (0.00000478)
# R-squared                                0.57569684
# R-squared Adj.                           0.44514202
# N                                        18
# R2                                       0.58
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    14.99697280***
#                                          (0.90173024)
# Energy distribution                      -0.00000248**
#                                          (0.00000086)
# Energy generation, non-renewable sources -0.00005785
#                                          (0.00005627)
# Energy Policy                            -0.00000466**
#                                          (0.00000192)
# Energy generation, renewable sources     0.00002144
#                                          (0.00001840)
# R-squared                                0.50316968
# R-squared Adj.                           0.35029881
# N                                        18
# R2                                       0.50
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    32.70901325***
#                                          (6.55225628)
# Energy distribution                      -0.00000007
#                                          (0.00000031)
# Energy generation, non-renewable sources 0.00000040
#                                          (0.00000046)
# Energy Policy                            -0.00000048
#                                          (0.00000133)
# Energy generation, renewable sources     0.00000004
#                                          (0.00000019)
# R-squared                                0.05571937
# R-squared Adj.                           -0.23482852
# N                                        18
# R2                                       0.06
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    61.21029816***
#                                          (1.58812366)
# Energy distribution                      -0.00000018
#                                          (0.00000011)
# Energy generation, non-renewable sources 0.00000000
#                                          (0.00000013)
# Energy Policy                            0.00000062
#                                          (0.00000074)
# Energy generation, renewable sources     -0.00000097*
#                                          (0.00000049)
# R-squared                                0.39398917
# R-squared Adj.                           0.20752430
# N                                        18
# R2                                       0.39
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    30.62342806***
#                                          (8.80826074)
# Energy distribution                      0.00105446
#                                          (0.00105467)
# Energy generation, non-renewable sources -0.00000000***
#                                          (0.00000000)
# Energy Policy                            0.00022674
#                                          (0.00018354)
# Energy generation, renewable sources     -0.00018626
#                                          (0.00021169)
# R-squared                                0.17587482
# R-squared Adj.                           -0.00072343
# N                                        18
# R2                                       0.18
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    39.83547290***
#                                          (1.89910433)
# Energy distribution                      0.00000008
#                                          (0.00000052)
# Energy generation, non-renewable sources 0.00000081
#                                          (0.00000046)
# Energy Policy                            0.00000608
#                                          (0.00000584)
# Energy generation, renewable sources     -0.00000100*
#                                          (0.00000054)
# R-squared                                0.50628855
# R-squared Adj.                           0.35437733
# N                                        18
# R2                                       0.51
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    51.32926624***
#                                          (3.63990901)
# Energy distribution                      0.00022638**
#                                          (0.00009550)
# Energy generation, non-renewable sources 0.00022638**
#                                          (0.00009550)
# Energy Policy                            -0.00029352*
#                                          (0.00014605)
# Energy generation, renewable sources     -0.00008607*
#                                          (0.00004098)
# R-squared                                0.51549260
# R-squared Adj.                           0.41166958
# N                                        18
# R2                                       0.52
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    30.61573467***
#                                          (8.96963462)
# Energy distribution                      -0.00000005
#                                          (0.00000010)
# Energy generation, non-renewable sources 0.00000039
#                                          (0.00000033)
# Energy Policy                            0.00000016
#                                          (0.00000051)
# Energy generation, renewable sources     -0.00000006
#                                          (0.00000017)
# R-squared                                0.17854010
# R-squared Adj.                           -0.07421679
# N                                        18
# R2                                       0.18
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    85.56744523***
#                                          (1.05543296)
# Energy distribution                      0.00008759
#                                          (0.00008240)
# Energy generation, non-renewable sources -0.00007338
#                                          (0.00006502)
# Energy Policy                            0.00020615
#                                          (0.00019223)
# Energy generation, renewable sources     -0.00009137
#                                          (0.00008220)
# R-squared                                0.36497750
# R-squared Adj.                           0.16958596
# N                                        18
# R2                                       0.36
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    49.38674177***
#                                          (3.61122321)
# Energy distribution                      -0.00000491**
#                                          (0.00000214)
# Energy generation, non-renewable sources 0.00000309
#                                          (0.00000392)
# Energy Policy                            -0.00000129
#                                          (0.00000096)
# Energy generation, renewable sources     0.00000455
#                                          (0.00000512)
# R-squared                                0.38896519
# R-squared Adj.                           0.20095448
# N                                        18
# R2                                       0.39
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    68.45137111***
#                                          (5.75635107)
# Energy distribution                      -0.00000027
#                                          (0.00000016)
# Energy generation, non-renewable sources 0.00000063
#                                          (0.00000081)
# Energy Policy                            0.00000038
#                                          (0.00000030)
# Energy generation, renewable sources     -0.00000120
#                                          (0.00000096)
# R-squared                                0.34173869
# R-squared Adj.                           0.13919675
# N                                        18
# R2                                       0.34
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    30.63332693***
#                                          (2.85885343)
# Energy distribution                      -0.00000054
#                                          (0.00000045)
# Energy generation, non-renewable sources -0.00000037
#                                          (0.00000047)
# Energy Policy                            0.00000062
#                                          (0.00000115)
# Energy generation, renewable sources     0.00000048
#                                          (0.00000107)
# R-squared                                0.33910449
# R-squared Adj.                           0.13575203
# N                                        18
# R2                                       0.34
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    17.33996133***
#                                          (3.86624383)
# Energy distribution                      0.00000151
#                                          (0.00000216)
# Energy generation, non-renewable sources 0.00000205
#                                          (0.00000242)
# Energy Policy                            -0.00003002*
#                                          (0.00001556)
# Energy generation, renewable sources     -0.00000263
#                                          (0.00000362)
# R-squared                                0.43243686
# R-squared Adj.                           0.25780205
# N                                        18
# R2                                       0.43
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    44.83844126***
#                                          (6.08723815)
# Energy distribution                      -0.00000002
#                                          (0.00000025)
# Energy generation, non-renewable sources 0.00000030
#                                          (0.00000038)
# Energy Policy                            -0.00000011
#                                          (0.00000028)
# Energy generation, renewable sources     -0.00000013
#                                          (0.00000015)
# R-squared                                0.36726007
# R-squared Adj.                           0.17257086
# N                                        18
# R2                                       0.37
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    22.38639400***
#                                          (5.05741197)
# Energy distribution                      -0.00000070
#                                          (0.00000140)
# Energy generation, non-renewable sources 0.00000198
#                                          (0.00000258)
# Energy Policy                            -0.00000533
#                                          (0.00000405)
# Energy generation, renewable sources     0.00000087
#                                          (0.00001075)
# R-squared                                0.17083460
# R-squared Adj.                           -0.08429322
# N                                        18
# R2                                       0.17
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    13.70472758***
#                                          (2.54016311)
# Energy distribution                      0.00000038
#                                          (0.00000036)
# Energy generation, non-renewable sources -0.00000031
#                                          (0.00000104)
# Energy Policy                            -0.00000091**
#                                          (0.00000040)
# Energy generation, renewable sources     -0.00000010
#                                          (0.00000008)
# R-squared                                0.50373516
# R-squared Adj.                           0.35103829
# N                                        18
# R2                                       0.50
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    20.50686540***
#                                          (1.90377011)
# Energy distribution                      0.00000035
#                                          (0.00000056)
# Energy generation, non-renewable sources -0.00000146
#                                          (0.00000145)
# Energy Policy                            -0.00000039
#                                          (0.00000038)
# Energy generation, renewable sources     -0.00000032
#                                          (0.00000042)
# R-squared                                0.22658214
# R-squared Adj.                           -0.01139258
# N                                        18
# R2                                       0.23
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ======================================================
#                                             Model 1
# ------------------------------------------------------
# const                                    9.69603589***
#                                          (1.15172785)
# Energy distribution                      -0.00000006
#                                          (0.00000007)
# Energy generation, non-renewable sources -0.00000007
#                                          (0.00000067)
# Energy Policy                            0.00000006
#                                          (0.00000043)
# Energy generation, renewable sources     -0.00000006
#                                          (0.00000025)
# R-squared                                0.15298963
# R-squared Adj.                           -0.10762895
# N                                        18
# R2                                       0.15
# ======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    28.14396836***
#                                          (5.77239428)
# Energy distribution                      0.00000033
#                                          (0.00000050)
# Energy generation, non-renewable sources -0.00000018
#                                          (0.00000046)
# Energy Policy                            0.00000195
#                                          (0.00000283)
# Energy generation, renewable sources     -0.00000097
#                                          (0.00000070)
# R-squared                                0.13500277
# R-squared Adj.                           -0.13115023
# N                                        18
# R2                                       0.14
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    35.81056567***
#                                          (2.76192774)
# Energy distribution                      0.00000008
#                                          (0.00000012)
# Energy generation, non-renewable sources -0.00000003
#                                          (0.00000029)
# Energy Policy                            -0.00000005
#                                          (0.00000014)
# Energy generation, renewable sources     -0.00000032**
#                                          (0.00000011)
# R-squared                                0.40317750
# R-squared Adj.                           0.21953980
# N                                        18
# R2                                       0.40
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    99.47351220***
#                                          (0.06369107)
# Energy distribution                      -0.00000034
#                                          (0.00000086)
# Energy generation, non-renewable sources -0.00000000
#                                          (0.00000001)
# Energy Policy                            -0.00000052
#                                          (0.00000032)
# Energy generation, renewable sources     -0.00000001*
#                                          (0.00000001)
# R-squared                                0.46428311
# R-squared Adj.                           0.29944714
# N                                        18
# R2                                       0.46
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    23.35318599***
#                                          (6.10745204)
# Energy distribution                      -0.00000014
#                                          (0.00000014)
# Energy generation, non-renewable sources -0.00000012*
#                                          (0.00000006)
# Energy Policy                            0.00000045
#                                          (0.00000033)
# Energy generation, renewable sources     -0.00000021
#                                          (0.00000017)
# R-squared                                0.45338144
# R-squared Adj.                           0.28519111
# N                                        18
# R2                                       0.45
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    44.01302144***
#                                          (2.02618734)
# Energy distribution                      0.00000043
#                                          (0.00000113)
# Energy generation, non-renewable sources -0.00000090
#                                          (0.00000085)
# Energy Policy                            0.00000360
#                                          (0.00000211)
# Energy generation, renewable sources     -0.00000004
#                                          (0.00000014)
# R-squared                                0.29447980
# R-squared Adj.                           0.07739666
# N                                        18
# R2                                       0.29
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    14.63535279***
#                                          (0.90738534)
# Energy distribution                      -0.00000024
#                                          (0.00000014)
# Energy generation, non-renewable sources -0.00000957
#                                          (0.00000915)
# Energy Policy                            0.00000278
#                                          (0.00000222)
# Energy generation, renewable sources     -0.00000087
#                                          (0.00000069)
# R-squared                                0.43549427
# R-squared Adj.                           0.26180020
# N                                        18
# R2                                       0.44
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    53.00260299***
#                                          (1.68640765)
# Energy distribution                      0.00000001
#                                          (0.00000004)
# Energy generation, non-renewable sources -0.00000000
#                                          (0.00000002)
# Energy Policy                            0.00000002
#                                          (0.00000005)
# Energy generation, renewable sources     -0.00000020**
#                                          (0.00000009)
# R-squared                                0.35805338
# R-squared Adj.                           0.16053135
# N                                        18
# R2                                       0.36
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    23.77280384***
#                                          (3.54044282)
# Energy distribution                      -0.00000022*
#                                          (0.00000011)
# Energy generation, non-renewable sources -0.00000019
#                                          (0.00000063)
# Energy Policy                            -0.00000006
#                                          (0.00000009)
# Energy generation, renewable sources     -0.00000015
#                                          (0.00000047)
# R-squared                                0.39679146
# R-squared Adj.                           0.21118883
# N                                        18
# R2                                       0.40
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    64.02803000***
#                                          (2.18643324)
# Energy distribution                      -0.00003760
#                                          (0.00003299)
# Energy generation, non-renewable sources 0.00000000***
#                                          (0.00000000)
# Energy Policy                            -0.00001500
#                                          (0.00002683)
# Energy generation, renewable sources     -0.00000215
#                                          (0.00000756)
# R-squared                                0.13170945
# R-squared Adj.                           -0.05435281
# N                                        18
# R2                                       0.13
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    59.12916426***
#                                          (2.80499187)
# Energy distribution                      -0.00000046
#                                          (0.00000030)
# Energy generation, non-renewable sources -0.00000030
#                                          (0.00000023)
# Energy Policy                            0.00000029
#                                          (0.00000023)
# Energy generation, renewable sources     -0.00000003
#                                          (0.00000018)
# R-squared                                0.37554871
# R-squared Adj.                           0.18340986
# N                                        18
# R2                                       0.38
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    98.44461361***
#                                          (0.50635369)
# Energy distribution                      -0.00000096
#                                          (0.00000350)
# Energy generation, non-renewable sources -0.00000000***
#                                          (0.00000000)
# Energy Policy                            -0.00000081
#                                          (0.00000099)
# Energy generation, renewable sources     -0.00000022
#                                          (0.00000013)
# R-squared                                0.22138090
# R-squared Adj.                           0.05453395
# N                                        18
# R2                                       0.22
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    16.69775045***
#                                          (2.55699067)
# Energy distribution                      0.00000016
#                                          (0.00000025)
# Energy generation, non-renewable sources -0.00000073
#                                          (0.00000163)
# Energy Policy                            -0.00000094*
#                                          (0.00000048)
# Energy generation, renewable sources     0.00000008
#                                          (0.00000034)
# R-squared                                0.24506485
# R-squared Adj.                           0.01277712
# N                                        18
# R2                                       0.25
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    23.22425292***
#                                          (2.33937963)
# Energy distribution                      0.00001449
#                                          (0.00004680)
# Energy generation, non-renewable sources -0.00000000***
#                                          (0.00000000)
# Energy Policy                            -0.00000009
#                                          (0.00000081)
# Energy generation, renewable sources     -0.00000422
#                                          (0.00000466)
# R-squared                                0.14839221
# R-squared Adj.                           -0.03409517
# N                                        18
# R2                                       0.15
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    82.79000229***
#                                          (0.90046582)
# Energy distribution                      0.00000000
#                                          (0.00000000)
# Energy generation, non-renewable sources 0.00000000
#                                          (0.00000000)
# Energy Policy                            0.00000001
#                                          (0.00000001)
# Energy generation, renewable sources     -0.00000001
#                                          (0.00000002)
# R-squared                                0.10658684
# R-squared Adj.                           -0.16830952
# N                                        18
# R2                                       0.11
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ======================================================
#                                             Model 1
# ------------------------------------------------------
# const                                    3.39259117***
#                                          (0.56021688)
# Energy distribution                      -0.00000035
#                                          (0.00000022)
# Energy generation, non-renewable sources 0.00000000***
#                                          (0.00000000)
# Energy Policy                            -0.00000093
#                                          (0.00000056)
# Energy generation, renewable sources     -0.00000115
#                                          (0.00000070)
# R-squared                                0.39854807
# R-squared Adj.                           0.26966552
# N                                        18
# R2                                       0.40
# ======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    41.98366920***
#                                          (2.61287056)
# Energy distribution                      0.00000014
#                                          (0.00000016)
# Energy generation, non-renewable sources -0.00000017
#                                          (0.00000010)
# Energy Policy                            -0.00000003
#                                          (0.00000012)
# Energy generation, renewable sources     -0.00000024
#                                          (0.00000032)
# R-squared                                0.25883068
# R-squared Adj.                           0.03077858
# N                                        18
# R2                                       0.26
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    16.32548672***
#                                          (4.42030262)
# Energy distribution                      -0.00000007
#                                          (0.00000005)
# Energy generation, non-renewable sources 0.00000074*
#                                          (0.00000036)
# Energy Policy                            0.00000085**
#                                          (0.00000039)
# Energy generation, renewable sources     -0.00000002
#                                          (0.00000009)
# R-squared                                0.56554281
# R-squared Adj.                           0.43186368
# N                                        18
# R2                                       0.57
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    40.24485559***
#                                          (2.70006385)
# Energy distribution                      -0.00000108
#                                          (0.00000107)
# Energy generation, non-renewable sources -0.00000036
#                                          (0.00000038)
# Energy Policy                            -0.00000499
#                                          (0.00000376)
# Energy generation, renewable sources     -0.00000073
#                                          (0.00000165)
# R-squared                                0.33779344
# R-squared Adj.                           0.13403757
# N                                        18
# R2                                       0.34
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# ======================================================
#                                             Model 1
# ------------------------------------------------------
# const                                    19.05547080**
#                                          (6.75994201)
# Energy distribution                      -0.00000016
#                                          (0.00000018)
# Energy generation, non-renewable sources 0.00000057
#                                          (0.00000060)
# Energy Policy                            -0.00000060
#                                          (0.00000056)
# Energy generation, renewable sources     0.00000018
#                                          (0.00000012)
# R-squared                                0.20714448
# R-squared Adj.                           -0.03681106
# N                                        18
# R2                                       0.21
# ======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    32.06148431***
#                                          (3.43186265)
# Energy distribution                      -0.00000024
#                                          (0.00000018)
# Energy generation, non-renewable sources 0.00000026
#                                          (0.00000046)
# Energy Policy                            -0.00000228
#                                          (0.00000260)
# Energy generation, renewable sources     0.00000006
#                                          (0.00000018)
# R-squared                                0.27148337
# R-squared Adj.                           0.04732440
# N                                        18
# R2                                       0.27
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
#
# =======================================================
#                                             Model 1
# -------------------------------------------------------
# const                                    37.62233205***
#                                          (1.24822877)
# Energy distribution                      -0.00000304
#                                          (0.00000536)
# Energy generation, non-renewable sources 0.00000830
#                                          (0.00008203)
# Energy Policy                            0.00000062
#                                          (0.00000070)
# Energy generation, renewable sources     0.00000006
#                                          (0.00000269)
# R-squared                                0.08663903
# R-squared Adj.                           -0.19439511
# N                                        18
# R2                                       0.09
# =======================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
results = summary_col([reg0],stars=True,float_format='%0.2f',
                       model_names=['Model 1'],
                       info_dict={'N':lambda x: "{0:d}".format(int(x.nobs)),
                                  'R2':lambda x: "{:.2f}".format(x.rsquared)})

print(results)
# Out:
# =================================================
#                                          Model 1
# -------------------------------------------------
# const                                    37.62***
#                                          (1.25)
# Energy distribution                      -0.00
#                                          (0.00)
# Energy generation, non-renewable sources 0.00
#                                          (0.00)
# Energy Policy                            0.00
#                                          (0.00)
# Energy generation, renewable sources     0.00
#                                          (0.00)
# R-squared                                0.09
# R-squared Adj.                           -0.19
# N                                        18
# R2                                       0.09
# =================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
