# %%
import os
import pandas as pd
import openpyxl
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col
from statsmodels.iolib.table import SimpleTable

# Set directory path to current directory
dir_path = os.path.abspath('')
gdp_path = os.path.abspath('../control-variables')

dat = os.path.join(dir_path, 'results_v1.xlsx')
gdp = os.path.join(gdp_path, 'inde-variable-data.xlsx')

# %%
df = pd.read_excel(dat, index_col=0, sheet_name="cum_gdp_elec")
df = pd.DataFrame(df)

# df.index = pd.Series(df.index).fillna(method='ffill')

# %%
coeffients = []

headers = ["Constant", "Energy Distribution", "Energy generation, nonrenewable", "Energy Policy", "Energy generation, renewable"]

countries = []

significance = []

rsq = []
rsq_adj = []

# %%
for name, group in df.groupby('country'):
    # print(name)
    
    y=group['dElec']
    
    print(y)

    # Model 1: The multiple regression model describes the response as a weighted sum of the predictors:(Elec = beta_0 + beta_1*ED + beta_2*EG,nr ~)
    X0 = group[['distribution cumulative',
                'nrgen cumulative',
                'policy cumulative',
                'rgen cumulative'               
                ]]
    
    X0 = sm.add_constant(X0)
    
    reg = sm.OLS(y, X0).fit()
    
    # print(reg.summary())
    
    coeffients.append(reg.params)
    rsq.append(reg.rsquared)
    rsq_adj.append(reg.rsquared_adj)
    # # # coeffients.extend([reg.params.values.flatten(), (100*reg.rsquared).astype(int), (100*reg.rsquared_adj).astype(int)])
    
    significance.append(reg.pvalues)

    countries.append(name)
# Out:
# country
# Angola    1.000000
# Angola    1.041001
# Angola    1.081599
# Angola    1.121754
# Angola    1.161564
# Angola    1.421323
# Angola    1.458846
# Angola    1.281244
# Angola    1.322010
# Angola    1.311407
# Angola    1.406201
# Angola    1.449711
# Angola    1.212862
# Angola    1.591882
# Angola    1.584202
# Angola    1.629845
# Angola    1.716579
# Angola    1.730994
# Name: dElec, dtype: float64
# country
# Benin    1.000000
# Benin    1.040599
# Benin    1.080745
# Benin    1.120394
# Benin    1.188595
# Benin    1.198784
# Benin    1.238049
# Benin    1.277716
# Benin    1.456988
# Benin    1.572013
# Benin    1.635916
# Benin    1.476425
# Benin    1.452728
# Benin    1.261871
# Benin    1.579839
# Benin    1.469769
# Benin    1.671642
# Benin    1.717658
# Name: dElec, dtype: float64
# country
# Botswana    1.000000
# Botswana    1.069255
# Botswana    1.138175
# Botswana    1.206727
# Botswana    1.274990
# Botswana    1.343157
# Botswana    1.404288
# Botswana    1.368313
# Botswana    1.634057
# Botswana    1.680097
# Botswana    1.763228
# Botswana    1.826859
# Botswana    1.891541
# Botswana    1.960639
# Botswana    2.028965
# Botswana    2.126944
# Botswana    2.157197
# Botswana    2.214773
# Name: dElec, dtype: float64
# country
# Burkina Faso    1.000000
# Burkina Faso    1.139080
# Burkina Faso    1.089760
# Burkina Faso    1.132943
# Burkina Faso    1.175213
# Burkina Faso    1.217179
# Burkina Faso    1.259463
# Burkina Faso    1.261981
# Burkina Faso    1.308943
# Burkina Faso    1.488738
# Burkina Faso    1.515070
# Burkina Faso    1.539274
# Burkina Faso    1.918451
# Burkina Faso    1.605774
# Burkina Faso    1.662619
# Burkina Faso    1.720267
# Burkina Faso    1.438838
# Burkina Faso    1.836432
# Name: dElec, dtype: float64
# country
# Burundi    1.000000
# Burundi    1.109006
# Burundi    1.214638
# Burundi    1.016693
# Burundi    0.843198
# Burundi    1.513688
# Burundi    1.521560
# Burundi    1.714842
# Burundi    1.680056
# Burundi    1.935848
# Burundi    2.060446
# Burundi    2.187242
# Burundi    2.218942
# Burundi    2.663709
# Burundi    2.932743
# Burundi    2.948022
# Burundi    3.359672
# Burundi    3.507448
# Name: dElec, dtype: float64
# country
# Cabo Verde    1.000000
# Cabo Verde    1.079580
# Cabo Verde    1.113128
# Cabo Verde    1.143345
# Cabo Verde    1.179671
# Cabo Verde    1.212813
# Cabo Verde    1.246008
# Cabo Verde    1.279365
# Cabo Verde    1.383959
# Cabo Verde    1.356107
# Cabo Verde    1.381435
# Cabo Verde    1.416295
# Cabo Verde    1.451497
# Cabo Verde    1.486974
# Cabo Verde    1.522657
# Cabo Verde    1.558477
# Cabo Verde    1.594365
# Cabo Verde    1.630265
# Name: dElec, dtype: float64
# country
# Cameroon    1.000000
# Cameroon    1.025018
# Cameroon    1.068848
# Cameroon    1.074305
# Cameroon    1.111965
# Cameroon    1.093810
# Cameroon    1.147152
# Cameroon    1.171673
# Cameroon    1.196549
# Cameroon    1.218623
# Cameroon    1.247895
# Cameroon    1.274415
# Cameroon    1.288971
# Cameroon    1.328732
# Cameroon    1.356346
# Cameroon    1.384143
# Cameroon    1.411515
# Cameroon    1.439933
# Name: dElec, dtype: float64
# country
# Central African Republic    1.000000
# Central African Republic    1.073166
# Central African Republic    1.144622
# Central African Republic    1.214206
# Central African Republic    1.253520
# Central African Republic    1.349950
# Central African Republic    1.201298
# Central African Republic    1.487740
# Central African Republic    1.573893
# Central African Republic    1.655916
# Central African Republic    1.749636
# Central African Republic    1.839936
# Central African Republic    1.935590
# Central African Republic    2.046981
# Central African Republic    2.167904
# Central African Republic    2.275569
# Central African Republic    2.353444
# Central African Republic    2.296599
# Name: dElec, dtype: float64
# country
# Chad    1.000000
# Chad    1.090490
# Chad    0.892090
# Chad    1.263073
# Chad    1.345551
# Chad    1.427251
# Chad    1.509762
# Chad    1.594676
# Chad    1.631249
# Chad    2.288847
# Chad    2.003190
# Chad    2.068589
# Chad    2.142486
# Chad    1.962597
# Chad    2.355360
# Chad    2.778222
# Chad    2.579800
# Chad    2.141015
# Name: dElec, dtype: float64
# country
# Comoros    1.000000
# Comoros    1.041513
# Comoros    1.092536
# Comoros    1.143299
# Comoros    1.193858
# Comoros    1.244348
# Comoros    1.294910
# Comoros    1.345682
# Comoros    1.566569
# Comoros    1.553781
# Comoros    1.546875
# Comoros    1.553353
# Comoros    1.606540
# Comoros    1.660085
# Comoros    1.713900
# Comoros    1.767894
# Comoros    1.821978
# Comoros    1.876077
# Name: dElec, dtype: float64
# country
# Congo, Dem. Rep.    1.000000
# Congo, Dem. Rep.    1.083223
# Congo, Dem. Rep.    1.165086
# Congo, Dem. Rep.    0.767194
# Congo, Dem. Rep.    1.324661
# Congo, Dem. Rep.    1.943558
# Congo, Dem. Rep.    1.482695
# Congo, Dem. Rep.    1.563120
# Congo, Dem. Rep.    1.645548
# Congo, Dem. Rep.    1.730774
# Congo, Dem. Rep.    1.969132
# Congo, Dem. Rep.    1.911068
# Congo, Dem. Rep.    1.726187
# Congo, Dem. Rep.    2.101638
# Congo, Dem. Rep.    2.199492
# Congo, Dem. Rep.    2.302399
# Congo, Dem. Rep.    2.397770
# Congo, Dem. Rep.    2.442235
# Name: dElec, dtype: float64
# country
# Cote d'Ivoire    1.000000
# Cote d'Ivoire    1.004344
# Cote d'Ivoire    1.023084
# Cote d'Ivoire    1.145914
# Cote d'Ivoire    1.170643
# Cote d'Ivoire    1.078206
# Cote d'Ivoire    1.173152
# Cote d'Ivoire    1.115064
# Cote d'Ivoire    1.133889
# Cote d'Ivoire    1.085603
# Cote d'Ivoire    1.085603
# Cote d'Ivoire    1.193139
# Cote d'Ivoire    1.204280
# Cote d'Ivoire    1.217899
# Cote d'Ivoire    1.250973
# Cote d'Ivoire    1.276265
# Cote d'Ivoire    1.306855
# Cote d'Ivoire    1.333660
# Name: dElec, dtype: float64
# country
# Eswatini    1.000000
# Eswatini    1.108704
# Eswatini    1.216998
# Eswatini    1.324840
# Eswatini    1.360181
# Eswatini    1.539702
# Eswatini    1.647197
# Eswatini    1.491562
# Eswatini    1.760211
# Eswatini    1.972830
# Eswatini    2.094796
# Eswatini    2.220460
# Eswatini    2.511698
# Eswatini    2.478151
# Eswatini    2.451030
# Eswatini    2.840150
# Eswatini    2.863700
# Eswatini    2.981951
# Name: dElec, dtype: float64
# country
# Ethiopia    1.000000
# Ethiopia    1.033828
# Ethiopia    1.067253
# Ethiopia    0.530716
# Ethiopia    1.132872
# Ethiopia    1.165453
# Ethiopia    1.198035
# Ethiopia    1.231033
# Ethiopia    1.264625
# Ethiopia    0.871890
# Ethiopia    1.334472
# Ethiopia    1.370809
# Ethiopia    1.031105
# Ethiopia    1.099339
# Ethiopia    1.626264
# Ethiopia    1.679336
# Ethiopia    1.707896
# Ethiopia    1.829893
# Name: dElec, dtype: float64
# country
# Gabon    1.000000
# Gabon    1.009199
# Gabon    1.018261
# Gabon    1.047983
# Gabon    1.035969
# Gabon    1.044725
# Gabon    1.053522
# Gabon    1.062440
# Gabon    1.149258
# Gabon    1.141447
# Gabon    1.146874
# Gabon    1.109629
# Gabon    1.117206
# Gabon    1.121569
# Gabon    1.132237
# Gabon    1.107960
# Gabon    1.153832
# Gabon    1.164664
# Name: dElec, dtype: float64
# country
# Gambia, The    1.000000
# Gambia, The    0.882493
# Gambia, The    1.102866
# Gambia, The    0.966814
# Gambia, The    1.204365
# Gambia, The    1.254872
# Gambia, The    1.305481
# Gambia, The    1.356388
# Gambia, The    1.505126
# Gambia, The    1.549587
# Gambia, The    1.593479
# Gambia, The    1.634833
# Gambia, The    1.680971
# Gambia, The    1.728356
# Gambia, The    1.777626
# Gambia, The    1.784032
# Gambia, The    1.914183
# Gambia, The    1.902162
# Name: dElec, dtype: float64
# country
# Ghana    1.000000
# Ghana    1.029890
# Ghana    1.086565
# Ghana    0.879564
# Ghana    1.174745
# Ghana    1.214873
# Ghana    1.290027
# Ghana    1.300531
# Ghana    1.368922
# Ghana    1.365991
# Ghana    1.204950
# Ghana    1.507520
# Ghana    1.669573
# Ghana    1.581532
# Ghana    1.690895
# Ghana    1.684499
# Ghana    1.714350
# Ghana    1.780451
# Name: dElec, dtype: float64
# country
# Guinea    1.000000
# Guinea    1.068190
# Guinea    1.135786
# Guinea    1.125963
# Guinea    1.269170
# Guinea    1.335437
# Guinea    1.401882
# Guinea    1.468852
# Guinea    1.536695
# Guinea    1.605758
# Guinea    1.460408
# Guinea    1.748173
# Guinea    1.821173
# Guinea    1.895069
# Guinea    1.867316
# Guinea    1.973223
# Guinea    2.452594
# Guinea    2.364433
# Name: dElec, dtype: float64
# country
# Kenya    1.000000
# Kenya    0.842763
# Kenya    1.200446
# Kenya    1.299774
# Kenya    1.398621
# Kenya    1.497307
# Kenya    1.596162
# Kenya    1.211472
# Kenya    1.011316
# Kenya    1.897016
# Kenya    1.999736
# Kenya    2.103726
# Kenya    1.896217
# Kenya    2.191184
# Kenya    2.796920
# Kenya    2.954487
# Kenya    3.236021
# Kenya    3.671287
# Name: dElec, dtype: float64
# country
# Lesotho     1.000000
# Lesotho     1.624039
# Lesotho     1.997847
# Lesotho     2.862439
# Lesotho     2.849869
# Lesotho     4.091149
# Lesotho     4.705992
# Lesotho     4.994616
# Lesotho     4.994616
# Lesotho     6.574457
# Lesotho     6.040548
# Lesotho     7.854352
# Lesotho     8.167667
# Lesotho     9.338192
# Lesotho    10.336362
# Lesotho     9.901092
# Lesotho    13.808645
# Lesotho    13.115474
# Name: dElec, dtype: float64
# country
# Madagascar    1.000000
# Madagascar    1.442374
# Madagascar    1.057244
# Madagascar    1.084659
# Madagascar    1.111425
# Madagascar    1.137975
# Madagascar    1.164751
# Madagascar    1.236321
# Madagascar    0.873951
# Madagascar    1.016057
# Madagascar    1.328690
# Madagascar    0.916583
# Madagascar    1.351693
# Madagascar    1.459690
# Madagascar    1.627112
# Madagascar    1.712375
# Madagascar    1.812955
# Madagascar    1.911834
# Name: dElec, dtype: float64
# country
# Malawi    1.000000
# Malawi    1.115375
# Malawi    1.241304
# Malawi    1.216550
# Malawi    0.657212
# Malawi    1.353009
# Malawi    1.421537
# Malawi    1.491759
# Malawi    1.565123
# Malawi    1.367234
# Malawi    1.331254
# Malawi    1.619092
# Malawi    2.140800
# Malawi    1.942911
# Malawi    1.978891
# Malawi    2.284719
# Malawi    3.241783
# Malawi    2.014870
# Name: dElec, dtype: float64
# country
# Mali    1.000000
# Mali    1.132822
# Mali    1.264832
# Mali    1.395954
# Mali    1.265199
# Mali    1.656572
# Mali    1.787008
# Mali    1.831558
# Mali    2.050509
# Mali    2.184525
# Mali    1.951150
# Mali    2.458422
# Mali    2.597821
# Mali    2.865752
# Mali    2.962323
# Mali    2.650820
# Mali    3.879435
# Mali    3.660026
# Name: dElec, dtype: float64
# country
# Mauritania    1.000000
# Mauritania    1.064646
# Mauritania    1.128797
# Mauritania    0.845778
# Mauritania    1.255591
# Mauritania    1.535437
# Mauritania    1.394139
# Mauritania    1.445455
# Mauritania    1.576627
# Mauritania    1.632599
# Mauritania    1.687739
# Mauritania    1.741889
# Mauritania    1.803087
# Mauritania    1.835617
# Mauritania    1.920852
# Mauritania    1.993619
# Mauritania    2.058392
# Mauritania    2.128947
# Name: dElec, dtype: float64
# country
# Mauritius    1.000000
# Mauritius    0.998128
# Mauritius    0.997810
# Mauritius    0.997376
# Mauritius    0.996849
# Mauritius    0.996292
# Mauritius    0.995766
# Mauritius    0.995336
# Mauritius    1.001911
# Mauritius    1.002012
# Mauritius    1.000969
# Mauritius    1.000194
# Mauritius    0.999754
# Mauritius    1.000300
# Mauritius    1.001443
# Mauritius    1.002113
# Mauritius    1.000202
# Mauritius    1.006036
# Name: dElec, dtype: float64
# country
# Mozambique    1.000000
# Mozambique    0.954440
# Mozambique    1.278043
# Mozambique    1.415064
# Mozambique    1.551008
# Mozambique    1.461119
# Mozambique    1.599126
# Mozambique    1.767482
# Mozambique    2.219674
# Mozambique    2.380209
# Mozambique    2.502368
# Mozambique    2.640151
# Mozambique    2.922237
# Mozambique    2.827971
# Mozambique    3.095369
# Mozambique    2.863321
# Mozambique    3.664580
# Mozambique    3.489736
# Name: dElec, dtype: float64
# country
# Namibia    1.000000
# Namibia    1.026338
# Namibia    1.052389
# Namibia    1.078124
# Namibia    1.103612
# Namibia    1.182054
# Namibia    1.154510
# Namibia    1.192874
# Namibia    1.206426
# Namibia    1.144185
# Namibia    1.260666
# Namibia    1.282136
# Namibia    1.317467
# Namibia    1.395743
# Namibia    1.344350
# Namibia    1.420088
# Namibia    1.459838
# Namibia    1.492989
# Name: dElec, dtype: float64
# country
# Niger    1.000000
# Niger    1.057417
# Niger    1.113639
# Niger    0.796586
# Niger    1.043416
# Niger    1.275991
# Niger    1.329895
# Niger    1.384857
# Niger    1.502890
# Niger    1.604392
# Niger    1.615612
# Niger    1.701332
# Niger    1.768957
# Niger    1.862441
# Niger    1.932854
# Niger    2.008869
# Niger    1.974637
# Niger    2.106435
# Name: dElec, dtype: float64
# country
# Nigeria    1.000000
# Nigeria    1.170581
# Nigeria    1.036311
# Nigeria    1.054086
# Nigeria    1.071656
# Nigeria    1.124182
# Nigeria    1.127974
# Nigeria    1.124516
# Nigeria    1.076397
# Nigeria    1.253554
# Nigeria    1.191973
# Nigeria    1.246826
# Nigeria    1.220466
# Nigeria    1.177309
# Nigeria    1.329798
# Nigeria    1.219916
# Nigeria    1.267009
# Nigeria    1.242341
# Name: dElec, dtype: float64
# country
# Rwanda    1.000000
# Rwanda    1.165778
# Rwanda    1.329968
# Rwanda    0.716460
# Rwanda    1.653504
# Rwanda    1.814134
# Rwanda    0.895575
# Rwanda    2.137753
# Rwanda    1.447846
# Rwanda    1.612035
# Rwanda    2.612094
# Rwanda    2.268790
# Rwanda    2.955397
# Rwanda    3.403185
# Rwanda    4.383839
# Rwanda    5.089851
# Rwanda    5.185713
# Rwanda    5.639500
# Name: dElec, dtype: float64
# country
# Sao Tome and Principe    1.000000
# Sao Tome and Principe    1.021068
# Sao Tome and Principe    1.041935
# Sao Tome and Principe    1.062580
# Sao Tome and Principe    1.083051
# Sao Tome and Principe    1.103465
# Sao Tome and Principe    1.123939
# Sao Tome and Principe    1.080742
# Sao Tome and Principe    1.165542
# Sao Tome and Principe    1.186908
# Sao Tome and Principe    1.099735
# Sao Tome and Principe    1.231102
# Sao Tome and Principe    1.302968
# Sao Tome and Principe    1.277588
# Sao Tome and Principe    1.318668
# Sao Tome and Principe    1.410662
# Sao Tome and Principe    1.348553
# Sao Tome and Principe    1.427983
# Name: dElec, dtype: float64
# country
# Senegal    1.000000
# Senegal    1.141996
# Senegal    1.000000
# Senegal    1.279891
# Senegal    1.355978
# Senegal    1.315491
# Senegal    1.358685
# Senegal    1.453804
# Senegal    1.535326
# Senegal    1.535326
# Senegal    1.535326
# Senegal    1.548913
# Senegal    1.657609
# Senegal    1.644022
# Senegal    1.752717
# Senegal    1.676630
# Senegal    1.793478
# Senegal    1.913043
# Name: dElec, dtype: float64
# country
# Seychelles    1.000000
# Seychelles    0.989186
# Seychelles    0.992569
# Seychelles    0.995830
# Seychelles    1.030177
# Seychelles    1.002131
# Seychelles    1.005298
# Seychelles    1.008564
# Seychelles    1.009365
# Seychelles    1.020597
# Seychelles    1.023176
# Seychelles    1.019771
# Seychelles    1.040583
# Seychelles    1.040583
# Seychelles    1.040583
# Seychelles    1.040583
# Seychelles    1.040583
# Seychelles    1.040583
# Name: dElec, dtype: float64
# country
# South Africa    1.000000
# South Africa    1.027379
# South Africa    1.054759
# South Africa    1.053455
# South Africa    1.052151
# South Africa    1.069100
# South Africa    1.067797
# South Africa    1.076923
# South Africa    1.080834
# South Africa    1.089961
# South Africa    1.112125
# South Africa    1.110821
# South Africa    1.121252
# South Africa    1.112125
# South Africa    1.097784
# South Africa    1.100391
# South Africa    1.104302
# South Africa    1.108214
# Name: dElec, dtype: float64
# country
# Sudan    1.000000
# Sudan    1.013654
# Sudan    1.026969
# Sudan    1.039911
# Sudan    1.052560
# Sudan    1.065107
# Sudan    1.077749
# Sudan    0.902116
# Sudan    1.185078
# Sudan    1.239924
# Sudan    1.294183
# Sudan    1.347724
# Sudan    1.396724
# Sudan    1.459717
# Sudan    1.519005
# Sudan    1.575762
# Sudan    1.626844
# Sudan    1.674423
# Name: dElec, dtype: float64
# country
# Tanzania    1.000000
# Tanzania    1.015694
# Tanzania    1.043145
# Tanzania    1.250244
# Tanzania    1.331788
# Tanzania    1.413052
# Tanzania    1.052296
# Tanzania    1.024844
# Tanzania    1.354259
# Tanzania    1.299356
# Tanzania    1.400011
# Tanzania    1.500665
# Tanzania    2.150343
# Tanzania    2.410469
# Tanzania    3.001330
# Tanzania    2.966413
# Tanzania    3.223634
# Tanzania    3.449700
# Name: dElec, dtype: float64
# country
# Togo    1.000000
# Togo    1.082402
# Togo    1.164307
# Togo    1.245668
# Togo    1.302502
# Togo    1.407395
# Togo    1.488336
# Togo    1.569716
# Togo    1.437502
# Togo    1.853380
# Togo    1.819329
# Togo    1.904821
# Togo    2.133488
# Togo    2.088761
# Togo    2.187176
# Togo    2.240863
# Togo    2.334232
# Togo    2.448194
# Name: dElec, dtype: float64
# country
# Uganda    1.000000
# Uganda    1.362590
# Uganda    1.501498
# Uganda    1.141026
# Uganda    1.153846
# Uganda    1.911003
# Uganda    2.047262
# Uganda    1.282051
# Uganda    1.551282
# Uganda    1.871795
# Uganda    2.612153
# Uganda    1.782051
# Uganda    2.615385
# Uganda    2.371795
# Uganda    3.423077
# Uganda    4.195456
# Uganda    5.474359
# Uganda    5.294872
# Name: dElec, dtype: float64
# country
# Zambia    1.000000
# Zambia    1.063218
# Zambia    1.166667
# Zambia    1.301346
# Zambia    1.338658
# Zambia    1.063218
# Zambia    1.413115
# Zambia    1.450977
# Zambia    1.264368
# Zambia    1.529758
# Zambia    1.571296
# Zambia    1.614220
# Zambia    1.603448
# Zambia    1.787356
# Zambia    2.021446
# Zambia    2.316092
# Zambia    2.288638
# Zambia    2.471264
# Name: dElec, dtype: float64
# country
# Zimbabwe    1.000000
# Zimbabwe    1.020898
# Zimbabwe    1.030692
# Zimbabwe    1.040145
# Zimbabwe    1.087719
# Zimbabwe    1.058427
# Zimbabwe    1.067617
# Zimbabwe    1.268102
# Zimbabwe    1.182988
# Zimbabwe    1.078947
# Zimbabwe    1.286550
# Zimbabwe    1.120946
# Zimbabwe    0.944444
# Zimbabwe    0.985380
# Zimbabwe    1.160124
# Zimbabwe    1.173809
# Zimbabwe    1.187613
# Zimbabwe    1.201436
# Name: dElec, dtype: float64

# %%
output = os.path.join(dir_path, 'model3_output.xlsx')
# print(significance)

p_df = pd.DataFrame(significance)

# Write the data into an excel sheet
with pd.ExcelWriter(output,w
                    engine='openpyxl',
                    mode='a',
                    if_sheeet_exists="overlay",
) as writer:
    writer.book = openpyxl.load_workbook(output)
    p_df.to_excel(writer, sheet_name='pvalue-eleccum')
# Out:
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Putting the coefficients into a table
tbl = SimpleTable(coeffients, headers, countries,
                  data_fmts=["%3.2f","%d"])

# Turning the table into a dataframe
tbl_df = pd.DataFrame(tbl, columns=["Country", "Constant", "Energy Distribution", "Energy generation, nonrenewable", "Energy Policy", "Energy generation, renewable"])

# Write grouped aid data to excel file

# Write the data into an excel sheet
with pd.ExcelWriter(output,
                    engine='openpyxl',
                    mode='a',
                    if_sheeet_exists="overlay",
) as writer:
    writer.book = openpyxl.load_workbook(output)
    tbl_df.to_excel(writer, sheet_name='coef-eleccum')
# Out:
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %%
# Turning array with r-squared and r-sqaured adjusted values into dataframes
rsq_df = pd.DataFrame(rsq, columns=['r-squared-eleccum'])
rsq_adj_df = pd.DataFrame(rsq_adj, columns=['r-squared adjusted-eleccum'])

# Turning the data into columns
rsq_df = rsq_df.transpose()
rsq_adj_df = rsq_adj_df.transpose()

# Concating two data together (Got overlapped because didn't reset index)
rsq_dat = pd.concat([rsq_df, rsq_adj_df], axis=1)

# Write the data into an excel sheet
with pd.ExcelWriter(output,
                    engine='openpyxl',
                    mode='a',
                    if_sheeet_exists="overlay",
) as writer:
    writer.book = openpyxl.load_workbook(output)
    rsq_dat.to_excel(writer, sheet_name='rsqua-eleccum')
# Out:
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   app.launch_new_instance()

# %% [markdown]
# reg operation:
#
# ['HC0_se', 'HC1_se', 'HC2_se', 'HC3_se', '_HCCM', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_abat_diagonal', '_cache', '_data_attr', '_data_in_cache', '_get_robustcov_results', '_is_nested', '_use_t', '_wexog_singular_values', 'aic', 'bic', 'bse', 'centered_tss', 'compare_f_test', 'compare_lm_test', 'compare_lr_test', 'condition_number', 'conf_int', 'conf_int_el', 'cov_HC0', 'cov_HC1', 'cov_HC2', 'cov_HC3', 'cov_kwds', 'cov_params', 'cov_type', 'df_model', 'df_resid', 'eigenvals', 'el_test', 'ess', 'f_pvalue', 'f_test', 'fittedvalues', 'fvalue', 'get_influence', 'get_prediction', 'get_robustcov_results', 'info_criteria', 'initialize', 'k_constant', 'llf', 'load', 'model', 'mse_model', 'mse_resid', 'mse_total', 'nobs', 'normalized_cov_params', 'outlier_test', 'params', 'predict', 'pvalues', 'remove_data', 'resid', 'resid_pearson', 'rsquared', 'rsquared_adj', 'save', 'scale', 'ssr', 'summary', 'summary2', 't_test', 't_test_pairwise', 'tvalues', 'uncentered_tss', 'use_t', 'wald_test', 'wald_test_terms', 'wresid']
