# %%
import os
import pandas as pd
import openpyxl
import statsmodels.api as sm
from statsmodels.iolib.summary2 import summary_col
from statsmodels.iolib.table import SimpleTable
from statsmodels.tsa.stattools import adfuller

# Set directory path to current directory
dir_path = os.path.abspath('../')
output_path = os.path.abspath('../outputs')

dat = os.path.join(dir_path, 'control_variables.xlsx')

# %%
df = pd.read_excel(dat, index_col=0, sheet_name="data")
df = pd.DataFrame(df)

# df.index = pd.Series(df.index).fillna(method='ffill')

# %%
def adf_test(timeseries):
    print("Results of Dickey-Fuller Test:")
    dftest = adfuller(timeseries, autolag="AIC")
    dfoutput = pd.Series(
        dftest[0:4],
        index=[
            "Test Statistic",
            "p-value",
            "#Lags Used",
            "Number of Observations Used",
        ],
    )
    for key, value in dftest[4].items():
        dfoutput["Critical Value (%s)" % key] = value
    print(dfoutput)

# %%
for name, group in df.groupby('country'):
    highest_elec_rate = group['elec_rate'].iloc[-1]
    print(f'For country {name}, the highest electrification rate is: \n{highest_elec_rate}')
# Out:
# For country Angola, the highest electrification rate is:
# 45.6703147888184
# For country Benin, the highest electrification rate is:
# 40.3187408447266
# For country Botswana, the highest electrification rate is:
# 70.1831817626953
# For country Burkina Faso, the highest electrification rate is:
# 18.3791522979736
# For country Burundi, the highest electrification rate is:
# 11.0647974014282
# For country Cabo Verde, the highest electrification rate is:
# 95.5335388183594
# For country Cameroon, the highest electrification rate is:
# 63.4523124694824
# For country Central African Republic, the highest electrification rate is:
# 14.3
# For country Chad, the highest electrification rate is:
# 8.4
# For country Comoros, the highest electrification rate is:
# 84.0482406616211
# For country Cote d'Ivoire, the highest electrification rate is:
# 68.5501098632813
# For country Eswatini, the highest electrification rate is:
# 77.1696395874023
# For country Ethiopia, the highest electrification rate is:
# 48.2716217041016
# For country Gabon, the highest electrification rate is:
# 90.6852569580078
# For country Gambia, The, the highest electrification rate is:
# 59.9212875366211
# For country Ghana, the highest electrification rate is:
# 83.5
# For country Guinea, the highest electrification rate is:
# 42.4183883666992
# For country Kenya, the highest electrification rate is:
# 69.7
# For country Lesotho, the highest electrification rate is:
# 44.6406784057617
# For country Madagascar, the highest electrification rate is:
# 26.9071846008301
# For country Malawi, the highest electrification rate is:
# 11.2
# For country Mali, the highest electrification rate is:
# 48.0212478637695
# For country Mauritania, the highest electrification rate is:
# 45.812068939209
# For country Mauritius, the highest electrification rate is:
# 100.0
# For country Mozambique, the highest electrification rate is:
# 29.6161613464355
# For country Namibia, the highest electrification rate is:
# 55.1951179504395
# For country Niger, the highest electrification rate is:
# 18.7747249603271
# For country Nigeria, the highest electrification rate is:
# 55.4
# For country Rwanda, the highest electrification rate is:
# 37.7824363708496
# For country Sao Tome and Principe, the highest electrification rate is:
# 75.1819076538086
# For country Senegal, the highest electrification rate is:
# 70.4
# For country Seychelles, the highest electrification rate is:
# 100.0
# For country South Africa, the highest electrification rate is:
# 85.0
# For country Sudan, the highest electrification rate is:
# 53.8270721435547
# For country Tanzania, the highest electrification rate is:
# 37.7
# For country Togo, the highest electrification rate is:
# 52.4410972595215
# For country Uganda, the highest electrification rate is:
# 41.3
# For country Zambia, the highest electrification rate is:
# 43.0
# For country Zimbabwe, the highest electrification rate is:
# 41.0891075134277

# %%
for name, group in df.groupby('country'):
    print(f'This is the ADf test results for {name}\'s changes in Electrifiction date')
    adf_test(group['elec_rate'])
# Out:
# This is the ADf test results for Angola's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 22.288260
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Benin's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                -5.697638e+00
# p-value                        7.807249e-07
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Botswana's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                -22.856687
# p-value                         0.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Burkina Faso's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.014685
# p-value                         0.994418
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Burundi's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.564321
# p-value                         0.997746
# #Lags Used                      3.000000
# Number of Observations Used    14.000000
# Critical Value (1%)            -4.012034
# Critical Value (5%)            -3.104184
# Critical Value (10%)           -2.690987
# dtype: float64
# This is the ADf test results for Cabo Verde's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.488740
# p-value                         0.894195
# #Lags Used                      1.000000
# Number of Observations Used    16.000000
# Critical Value (1%)            -3.924019
# Critical Value (5%)            -3.068498
# Critical Value (10%)           -2.673893
# dtype: float64
# This is the ADf test results for Cameroon's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.332564
# p-value                         0.996785
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Central African Republic's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                -1.591039e+01
# p-value                        8.136286e-29
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Chad's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.774999
# p-value                         0.392943
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Comoros's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.541015
# p-value                         0.105811
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Cote d'Ivoire's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.671323
# p-value                         0.998057
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Eswatini's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.334435
# p-value                         0.920484
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Ethiopia's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.902765
# p-value                         0.998532
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Gabon's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                -8.311588e+00
# p-value                        3.776193e-13
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Gambia, The's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.129578
# p-value                         0.232789
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Ghana's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.584461
# p-value                         0.997810
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Guinea's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  2.032289
# p-value                         0.998713
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Kenya's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  3.146777
# p-value                         1.000000
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Lesotho's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  2.102606
# p-value                         0.998792
# #Lags Used                      4.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64
# This is the ADf test results for Madagascar's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.215873
# p-value                         0.666731
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Malawi's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.835507
# p-value                         0.362981
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Mali's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  2.261098
# p-value                         0.998929
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Mauritania's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.242605
# p-value                         0.933249
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Mauritius's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.024830
# p-value                         0.744101
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Mozambique's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  0.067354
# p-value                         0.963760
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Namibia's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  2.821464
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Niger's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.188649
# p-value                         0.939861
# #Lags Used                      1.000000
# Number of Observations Used    16.000000
# Critical Value (1%)            -3.924019
# Critical Value (5%)            -3.068498
# Critical Value (10%)           -2.673893
# dtype: float64
# This is the ADf test results for Nigeria's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.984941
# p-value                         0.758717
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Rwanda's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.176972
# p-value                         0.995823
# #Lags Used                      1.000000
# Number of Observations Used    16.000000
# Critical Value (1%)            -3.924019
# Critical Value (5%)            -3.068498
# Critical Value (10%)           -2.673893
# dtype: float64
# This is the ADf test results for Sao Tome and Principe's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.607810
# p-value                         0.997881
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Senegal's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.400572
# p-value                         0.997117
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Seychelles's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.253101
# p-value                         0.931889
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for South Africa's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                -6.996846e+00
# p-value                        7.495443e-10
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Sudan's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                -1.012863e+01
# p-value                        9.040839e-18
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Tanzania's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  0.966208
# p-value                         0.993896
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Togo's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  0.079901
# p-value                         0.964662
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Uganda's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  1.299367
# p-value                         0.996605
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Zambia's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                  2.808063
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Zimbabwe's changes in Electrifiction date
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.004628
# p-value                         0.034464
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64

# %%
for name, group in df.groupby('country'):
    print(f'This is the ADf test results for {name}\'s changes in CPI')
    adf_test(group['dCPI'])
# Out:
# This is the ADf test results for Angola's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  5.944708
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Benin's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.103364
# p-value                         0.000014
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Botswana's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.429704
# p-value                         0.000003
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Burkina Faso's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                -1.055307e+01
# p-value                        8.082090e-19
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Burundi's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.061737
# p-value                         0.730087
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Cabo Verde's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.247460
# p-value                         0.189473
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Cameroon's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.458550
# p-value                         0.553907
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Central African Republic's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 39.964433
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Chad's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.648748
# p-value                         0.004895
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Comoros's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.333560
# p-value                         0.161373
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Cote d'Ivoire's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.315801
# p-value                         0.621913
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Eswatini's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 96.320923
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Ethiopia's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  2.132229
# p-value                         0.998822
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Gabon's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.107831
# p-value                         0.995283
# #Lags Used                      1.000000
# Number of Observations Used    16.000000
# Critical Value (1%)            -3.924019
# Critical Value (5%)            -3.068498
# Critical Value (10%)           -2.673893
# dtype: float64
# This is the ADf test results for Gambia, The's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  3.254663
# p-value                         1.000000
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Ghana's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  2.121796
# p-value                         0.998812
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Guinea's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.432062
# p-value                         0.997255
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Kenya's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.075565
# p-value                         0.995003
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Lesotho's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.386090
# p-value                         0.997050
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Madagascar's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  4.736519
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Malawi's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.596558
# p-value                         0.997847
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Mali's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                -1.538469e+01
# p-value                        3.371326e-28
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Mauritania's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                -5.684080e+00
# p-value                        8.356855e-07
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Mauritius's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                -6.078506e+00
# p-value                        1.106635e-07
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Mozambique's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.279312
# p-value                         0.996491
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Namibia's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  3.529253
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Niger's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.616922
# p-value                         0.005446
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Nigeria's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.017276
# p-value                         0.994445
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Rwanda's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.971035
# p-value                         0.763681
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Sao Tome and Principe's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.111202
# p-value                         0.948311
# #Lags Used                      4.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64
# This is the ADf test results for Senegal's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.044131
# p-value                         0.736831
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Seychelles's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  0.311397
# p-value                         0.977861
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for South Africa's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  2.182510
# p-value                         0.998868
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Sudan's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  2.435587
# p-value                         0.999026
# #Lags Used                      5.000000
# Number of Observations Used    12.000000
# Critical Value (1%)            -4.137829
# Critical Value (5%)            -3.154972
# Critical Value (10%)           -2.714477
# dtype: float64
# This is the ADf test results for Tanzania's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.303265
# p-value                         0.996627
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Togo's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.518103
# p-value                         0.524538
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Uganda's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  0.421023
# p-value                         0.982264
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Zambia's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  3.141029
# p-value                         1.000000
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Zimbabwe's changes in CPI
# Results of Dickey-Fuller Test:
# Test Statistic                  1.487202
# p-value                         0.997476
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64

# %%
for name, group in df.groupby('country'):
    print(f'This is the ADf test results for {name}\'s cumulative value for aid in energy distribution')
    adf_test(group['distribution cumulative'])
# Out:
# This is the ADf test results for Angola's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.649014
# p-value                         0.859518
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Benin's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.199437
# p-value                         0.020017
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Botswana's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -3.155046e+13
# p-value                        0.000000e+00
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Burkina Faso's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.734119
# p-value                         0.413625
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Burundi's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.769728
# p-value                         0.827853
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Cabo Verde's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.679523
# p-value                         0.004411
# #Lags Used                      3.000000
# Number of Observations Used    14.000000
# Critical Value (1%)            -4.012034
# Critical Value (5%)            -3.104184
# Critical Value (10%)           -2.690987
# dtype: float64
# This is the ADf test results for Cameroon's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.339419
# p-value                         0.610951
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Central African Republic's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.787676
# p-value                         0.060056
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Chad's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.059710
# p-value                         0.029682
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Comoros's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# Test Statistic                -42.579953
# p-value                         0.000000
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Cote d'Ivoire's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.663052
# p-value                         0.450243
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Eswatini's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 19.763340
# p-value                         1.000000
# #Lags Used                      2.000000
# Number of Observations Used    15.000000
# Critical Value (1%)            -3.964443
# Critical Value (5%)            -3.084908
# Critical Value (10%)           -2.681814
# dtype: float64
# This is the ADf test results for Ethiopia's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                  0.137508
# p-value                         0.968531
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Gabon's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -8.746468e+00
# p-value                        2.913664e-14
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.700000e+01
# Critical Value (1%)           -3.889266e+00
# Critical Value (5%)           -3.054358e+00
# Critical Value (10%)          -2.666984e+00
# dtype: float64
# This is the ADf test results for Gambia, The's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.926960
# p-value                         0.319486
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Ghana's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.429119
# p-value                         0.000264
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Guinea's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -7.239620e+00
# p-value                        1.899354e-10
# #Lags Used                     0.000000e+00
# Number of Observations Used    1.700000e+01
# Critical Value (1%)           -3.889266e+00
# Critical Value (5%)           -3.054358e+00
# Critical Value (10%)          -2.666984e+00
# dtype: float64
# This is the ADf test results for Kenya's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                  1.204988
# p-value                         0.996020
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Lesotho's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -26.344498
# p-value                         0.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Madagascar's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.750840
# p-value                         0.000067
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Malawi's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.134319
# p-value                         0.024116
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Mali's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -7.339357e+00
# p-value                        1.075334e-10
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Mauritania's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                  1.082319
# p-value                         0.995063
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Mauritius's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.003772
# p-value                         0.751886
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Mozambique's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                  5.556904
# p-value                         1.000000
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Namibia's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.818426
# p-value                         0.813650
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Niger's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.307879
# p-value                         0.924381
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Nigeria's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -5.251736
# p-value                         0.000007
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Rwanda's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.458077
# p-value                         0.554139
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Sao Tome and Principe's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -1.612702e+01
# p-value                        4.829896e-29
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Senegal's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.233461
# p-value                         0.659039
# #Lags Used                      7.000000
# Number of Observations Used    10.000000
# Critical Value (1%)            -4.331573
# Critical Value (5%)            -3.232950
# Critical Value (10%)           -2.748700
# dtype: float64
# This is the ADf test results for Seychelles's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.903696
# p-value                         0.786753
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for South Africa's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.095216
# p-value                         0.949913
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Sudan's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                  0.186284
# p-value                         0.971482
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# This is the ADf test results for Tanzania's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                -9.361239e+00
# p-value                        7.812785e-16
# #Lags Used                     7.000000e+00
# Number of Observations Used    1.000000e+01
# Critical Value (1%)           -4.331573e+00
# Critical Value (5%)           -3.232950e+00
# Critical Value (10%)          -2.748700e+00
# dtype: float64
# This is the ADf test results for Togo's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.475541
# p-value                         0.121540
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Uganda's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.153083
# p-value                         0.223712
# #Lags Used                      5.000000
# Number of Observations Used    12.000000
# Critical Value (1%)            -4.137829
# Critical Value (5%)            -3.154972
# Critical Value (10%)           -2.714477
# dtype: float64
# This is the ADf test results for Zambia's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.585293
# p-value                         0.490977
# #Lags Used                      6.000000
# Number of Observations Used    11.000000
# Critical Value (1%)            -4.223238
# Critical Value (5%)            -3.189369
# Critical Value (10%)           -2.729839
# dtype: float64
# This is the ADf test results for Zimbabwe's cumulative value for aid in energy distribution
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.599563
# p-value                         0.483813
# #Lags Used                      0.000000
# Number of Observations Used    17.000000
# Critical Value (1%)            -3.889266
# Critical Value (5%)            -3.054358
# Critical Value (10%)           -2.666984
# dtype: float64
# /opt/anaconda3/envs/MyPythonProject/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:924: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2

# %%
coeffients = []

headers = ["Constant", "Energy Distribution", "Energy generation, nonrenewable", "Energy Policy", "Energy generation, renewable", "GDP", "CPI", "Governance", "Trade openness"]

countries = []

significance = []

rsq = []
rsq_adj = []

# %%
for name, group in df.groupby('country'):
    # print(name)
    
    y=group['dElec']

    # Model 1: The multiple regression model describes the response as a weighted sum of the predictors:(Elec = beta_0 + beta_1*ED + beta_2*EG,nr ~)
    X0 = group[['distribution cumulative',
                'nrgen cumulative',
                'policy cumulative',
                'rgen cumulative',
                'dGDP',
                'dCPI',
                'governance',
                'trade'               
                ]]
    
    X0 = sm.add_constant(X0)
    
    reg = sm.OLS(y, X0).fit()
    
    # print(reg.summary())
    
    coeffients.append(reg.params)
    rsq.append(reg.rsquared)
    rsq_adj.append(reg.rsquared_adj)
    # coeffients.extend([reg.params.values.flatten(), (100*reg.rsquared).astype(int), (100*reg.rsquared_adj).astype(int)])
    
    significance.append(reg.pvalues)

    countries.append(name)

# %%
output = os.path.join(output_path, 'model4_output.xlsx')
# print(significance)

p_df = pd.DataFrame(significance)

# Write the data into an excel sheet
with pd.ExcelWriter(output,
                    engine='openpyxl',
                    mode='a',
                    if_sheet_exists="new",
) as writer:
    writer.book = openpyxl.load_workbook(output)
    p_df.to_excel(writer, sheet_name='pvalue-eleccum')

# %%
# Putting the coefficients into a table
tbl = SimpleTable(coeffients, headers, countries,
                  data_fmts=["%3.2f","%d"])

# Turning the table into a dataframe
tbl_df = pd.DataFrame(tbl, columns=["Country", "Constant", "Energy Distribution", "Energy generation, nonrenewable", "Energy Policy", "Energy generation, renewable", "GDP", "CPI", "Governance", "Trade openness"])

# Write grouped aid data to excel file

# Write the data into an excel sheet
with pd.ExcelWriter(output,
                    engine='openpyxl',
                    mode='a',
                    if_sheet_exists="new",
) as writer:
    writer.book = openpyxl.load_workbook(output)
    tbl_df.to_excel(writer, sheet_name='coef-eleccum')

# %%
# Turning array with r-squared and r-sqaured adjusted values into dataframes
rsq_df = pd.DataFrame(rsq, columns=['r-squared-eleccum'])
rsq_adj_df = pd.DataFrame(rsq_adj, columns=['r-squared adjusted-eleccum'])

# Turning the data into columns
# rsq_df = rsq_df.transpose()
# rsq_adj_df = rsq_adj_df.transpose()

# Concating two data together (Got overlapped because didn't reset index)
rsq_dat = pd.concat([rsq_df, rsq_adj_df], axis=1)

# Write the data into an excel sheet
with pd.ExcelWriter(output,
                    engine='openpyxl',
                    mode='a',
                    if_sheet_exists="new",
) as writer:
    writer.book = openpyxl.load_workbook(output)
    rsq_dat.to_excel(writer, sheet_name='rsqua-eleccum')

# %% [markdown]
# reg operation:
#
# ['HC0_se', 'HC1_se', 'HC2_se', 'HC3_se', '_HCCM', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_abat_diagonal', '_cache', '_data_attr', '_data_in_cache', '_get_robustcov_results', '_is_nested', '_use_t', '_wexog_singular_values', 'aic', 'bic', 'bse', 'centered_tss', 'compare_f_test', 'compare_lm_test', 'compare_lr_test', 'condition_number', 'conf_int', 'conf_int_el', 'cov_HC0', 'cov_HC1', 'cov_HC2', 'cov_HC3', 'cov_kwds', 'cov_params', 'cov_type', 'df_model', 'df_resid', 'eigenvals', 'el_test', 'ess', 'f_pvalue', 'f_test', 'fittedvalues', 'fvalue', 'get_influence', 'get_prediction', 'get_robustcov_results', 'info_criteria', 'initialize', 'k_constant', 'llf', 'load', 'model', 'mse_model', 'mse_resid', 'mse_total', 'nobs', 'normalized_cov_params', 'outlier_test', 'params', 'predict', 'pvalues', 'remove_data', 'resid', 'resid_pearson', 'rsquared', 'rsquared_adj', 'save', 'scale', 'ssr', 'summary', 'summary2', 't_test', 't_test_pairwise', 'tvalues', 'uncentered_tss', 'use_t', 'wald_test', 'wald_test_terms', 'wresid']
